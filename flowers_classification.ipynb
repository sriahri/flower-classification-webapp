# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os

# %%
os.listdir('/content/gdrive/MyDrive/flowers/train')
# Out:
# ['sunflower', 'dandelion', 'tulip', 'rose', 'daisy']

# %%
# !unzip -o 'gdrive/My Drive/archive.zip' -d flowers

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten,Dropout
from keras.layers import Dense


classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(128, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(128, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Conv2D(64,(3,3),activation='relu'))
classifier.add(Dropout(rate=0.1))
# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 5, activation = 'softmax'))

classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('/content/gdrive/MyDrive/flowers/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

#test_set = test_datagen.flow_from_directory('data3/asl_alphabet_test',
                                   #         target_size = (64, 64),
                                #            batch_size = 32,
                                      #      class_mode = 'categorical')
# Out:
# Found 4323 images belonging to 5 classes.

# %%
#import tensorflow as tf

# %%
batch_size=32
# checkpoin
from keras.callbacks import ModelCheckpoint
weightpath = "gdrive/My Drive/best_weights_flowers.hdf9"
checkpoint = ModelCheckpoint(weightpath, monitor='val_acc', verbose=1, save_best_only=False, save_weights_only=True, mode='max')
callbacks_list = [checkpoint]


classifier.fit(x = training_set,steps_per_epoch = 135,epochs = 200,validation_data = training_set,validation_steps = 32,callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 135/135 [==============================] - 22s 160ms/step - loss: 1.1181 - accuracy: 0.5442 - val_loss: 1.1005 - val_accuracy: 0.5654
#
# Epoch 00001: saving model to gdrive/My Drive/best_weights_flowers.hdf9
# Epoch 2/200
# 135/135 [==============================] - 22s 159ms/step - loss: 1.0192 - accuracy: 0.5922 - val_loss: 0.9498 - val_accuracy: 0.6260
#
# Epoch 00002: saving model to gdrive/My Drive/best_weights_flowers.hdf9
# Epoch 3/200
# 135/135 [==============================] - 22s 160ms/step - loss: 0.9496 - accuracy: 0.6150 - val_loss: 0.8522 - val_accuracy: 0.6787
#
# Epoch 00003: saving model to gdrive/My Drive/best_weights_flowers.hdf9
# Epoch 4/200
# 135/135 [==============================] - 22s 160ms/step - loss: 0.8752 - accuracy: 0.6551 - val_loss: 0.9100 - val_accuracy: 0.6328
#
# Epoch 00004: saving model to gdrive/My Drive/best_weights_flowers.hdf9
# Epoch 5/200
# ...

# %% [markdown]
# # New Section

# %%
a=training_set.class_indices.keys()
a=list(a)
print(a)
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/gdrive/MyDrive/sunflower.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image.reshape(1,64,64,3)
test_image = np.expand_dims(test_image, axis = 0)
test_image=test_image/255
result =classifier.predict(test_image)
print(a[(np.argmax(result))])
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
# sunflower

# %%
classifier.save("model.h5")
